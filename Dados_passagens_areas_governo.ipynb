# %%
import pandas as pd

# %%
df = pd.read_excel('C:/Users/1831133133/Downloads/201710_EmissaoPassagens_SCDP.xlsx',skiprows=3,skip_footer=3)

# %%
df.head(1)
# Out:
#     Código do órgão superior  \
# 0                          3
#
#                                  Nome do órgão superior                                  \
# 0   Fundação Instituto Brasileiro de Geografia e ...
#
#     Código do órgão solicitante da viagem  \
# 0                                       3
#
#                                         Nome do órgão solicitante da viagem                                         \
# 0   Fundação Instituto Brasileiro de Geografia e ...
#
#        N. PCDP        N. Reserva/Localizador   Data Emissão Bilhete     \
# 0   028012/17        JGZQXC                    2017-10-03 11:33:35.808
#
#       Data Embarque       Valor Tarifa Comercial  \
# 0   2017-10-06 20:55:00                    407.4
#
#     Percentual Desconto Aplicado           ...             \
# 0                            0.0           ...
#
#               Companhia Aérea                Classe Tarifária Bilhete  \
# 0   LATAM AIRLINES BRASIL                   N
#
# ...

# %%
df.dtypes
# Out:
#  Código do órgão superior                                                                                             int64
#                                Nome do órgão superior                                                                object
#  Código do órgão solicitante da viagem                                                                                int64
#                                       Nome do órgão solicitante da viagem                                            object
#     N. PCDP                                                                                                          object
#  N. Reserva/Localizador                                                                                              object
#   Data Emissão Bilhete                                                                                               object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50405 entries, 0 to 50404
# Data columns (total 23 columns):
#  Código do órgão superior                                                                                           50405 non-null int64
#                                Nome do órgão superior                                                               50405 non-null object
#  Código do órgão solicitante da viagem                                                                              50405 non-null int64
#                                       Nome do órgão solicitante da viagem                                           50405 non-null object
#     N. PCDP                                                                                                         50405 non-null object
#  N. Reserva/Localizador                                                                                             50405 non-null object
# ...

# %%
df.describe()
# Out:
#         Código do órgão superior   Código do órgão solicitante da viagem  \
# count               50405.000000                            50405.000000
# mean                16489.825176                            47696.792084
# std                 36709.186923                            50214.945925
# min                     3.000000                          -122771.000000
# 25%                   315.000000                             3418.000000
# 50%                   471.000000                            32207.000000
# 75%                  2207.000000                            86558.000000
# max                219924.000000                           224227.000000
#
#         Valor Tarifa Comercial   Percentual Desconto Aplicado  \
# count             50405.000000                   50405.000000
# mean                678.273258                       2.078992
# std                 432.242664                       3.211066
# ...

# %%
df.sample(3).T ## transpor tbela
# Out:
#                                                                                                 17016  \
#  Código do órgão superior                                                                         415
#                                Nome do órgão su...   Universidade Federal do Pará                 ...
#  Código do órgão solicitante da viagem                                                          35605
#                                       Nome do ó...   Secretaria - Geral                           ...
#     N. PCDP                                                                            004772/17-3C
#  N. Reserva/Localizador                                                       X86RFY
#   Data Emissão Bilhete                                                        2017-10-27 19:29:27.802
#     Data Embarque                                                                 2017-10-30 12:25:00
# ...

# %%
df.head()
# Out:
#     Código do órgão superior  \
# 0                          3
# 1                          3
# 2                          3
# 3                          3
# 4                          3
#
#                                  Nome do órgão superior                                  \
# 0   Fundação Instituto Brasileiro de Geografia e ...
# 1   Fundação Instituto Brasileiro de Geografia e ...
# 2   Fundação Instituto Brasileiro de Geografia e ...
# 3   Fundação Instituto Brasileiro de Geografia e ...
# 4   Fundação Instituto Brasileiro de Geografia e ...
#
#     Código do órgão solicitante da viagem  \
# 0                                       3
# 1                                       3
# 2                                       3
# 3                                       3
# 4                                       3
#
#                                         Nome do órgão solicitante da viagem                                         \
# ...

# %%
df.sample(3).T ## transpor tbela
# Out:
#                                                                                                 11692  \
#  Código do órgão superior                                                                         304
#                                Nome do órgão su...   Ministério da Saúde                          ...
#  Código do órgão solicitante da viagem                                                         111119
#                                       Nome do ó...   Serviço de Gestão Administrativa             ...
#     N. PCDP                                                                            037990/17
#  N. Reserva/Localizador                                                       WNL58K
#   Data Emissão Bilhete                                                        2017-10-17 19:16:52.993
#     Data Embarque                                                                 2017-10-29 16:50:00
# ...

# %%
#df['Nome do órgão superior'].value_counts().plot.barh()

# %%
df['Nome_do_orgao_Superior']=df['                               Nome do órgão superior                                ']

# %%
# %matplotlib inline

# %%
df['Nome_Org_Superior']=df ['Nome_do_orgao_Superior'].str.split(' ').str[1]

# %%
df['Nome_Org_Superior'].value_counts()
# Out:
# Ministério          13149
# Instituto            9862
# Universidade         7833
# Fundação             6114
# Departamento         5131
# Agência              2918
# Comando              2471
# Secretaria            796
# Comissão              553
# Advocacia-Geral       532
# Superintendência      358
# Casa                  172
# Centro                149
# Secretaria-Geral       93
# Presidência            79
# Gabinete               76
# Empresa                48
# Colégio                37
# Conselho               28
# Caixa                   6
# Name: Nome_Org_Superior, dtype: int64

# %%
df['Nome_Org_Superior'].value_counts().plot.barh()
plt.title('Numero de Bilhetes por Orgao Superior')
# Out:
# Text(0.5,1,'Numero de Bilhetes por Orgao Superior')

# %%
df.groupby(['Nome_Org_Superior'])[' Valor Bilhete'].sum()
# Out:
# Nome_Org_Superior
# Advocacia-Geral      318819.92
# Agência             1833968.02
# Caixa                  2830.00
# Casa                 116073.35
# Centro                70450.55
# Colégio               21694.76
# Comando             1732054.74
# Comissão             276419.94
# Conselho              19009.68
# Departamento        3921629.24
# Empresa               38676.78
# Fundação            4250020.71
# Gabinete              59615.08
# Instituto           7352439.17
# Ministério          9549884.22
# Presidência           51026.84
# Secretaria           625266.76
# Secretaria-Geral      83319.77
# Superintendência     252309.90
# Universidade        4448698.01
# Name:  Valor Bilhete, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
df.groupby(['Nome_Org_Superior'])[' Valor Bilhete'].sum().plot.barh()
plt.title('Gastos por Orgão Superior')
plt.ylabel('')
plt.xlabel('')
# Out:
# Text(0.5,0,'')

# %%
df.groupby(['           Companhia Aérea            '])[' Valor Bilhete'].sum()
# Out:
#            Companhia Aérea
#  AVIANCA S.A.                              5245246.64
#  AZUL LINHAS AÉREAS BRASILEIRA             8020100.45
#  GOL Linhas Aéreas Inteligentes           12936609.65
#  Gol OU Latam - Parceria com Terceiro       162520.18
#  LATAM AIRLINES BRASIL                     8457533.31
#  MAP TRANSPORTES AEREOS LTDA - MAP          202197.21
# Name:  Valor Bilhete, dtype: float64

# %%
df.groupby(['           Companhia Aérea            '])[' Valor Bilhete'].sum().plot.pie()
plt.ylabel('')
plt.xlabel('')
plt.title('Valores por companhia')
# Out:
# Text(0.5,1,'Valores por companhia')
